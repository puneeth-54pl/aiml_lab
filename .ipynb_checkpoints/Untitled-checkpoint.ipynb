# %%
print("hello world")
# Out:
# hello world

# %%
n=int(input("Enter a number:"))
print(f"Given number is {n}")
# Out:
# Enter a number: 23
# Given number is 23

# %%
import pandas as pd
import matplotlib.pyplot as plt
data1={"semester":["1","2","3","4"],
       "percentage":[89.9,91.2,90,95.4]}
df=pd.DataFrame(data1)
print(df)
# Out:
#   semester  percentage
# 0        1        89.9
# 1        2        91.2
# 2        3        90.0
# 3        4        95.4

# %%
plt.plot(df["semester"],df["percentage"],color="red",marker="o")
plt.title("Student results chart")
plt.xlabel("Semester")
plt.ylabel("Percentage scored")
plt.show()

# %%
df.head(2)
# Out:
#   semester  percentage
# 0        1        89.9
# 1        2        91.2

# %%
df.to_csv("data.csv")

# %%
from_csv=pd.read_csv("data.csv")
print(type(from_csv))
print(from_csv)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Unnamed: 0  semester  percentage
# 0           0         1        89.9
# 1           1         2        91.2
# 2           2         3        90.0
# 3           3         4        95.4

# %%
new_series=pd.Series([1,2,3,4,0,5],index=['a','b','c','d','e','f'])

# %%
add_ser=pd.Series([6,7,8],index=[1,2,3])

# %%
print(add_ser)
# Out:
# 1    6
# 2    7
# 3    8
# dtype: int64

# %%
print(pd.concat([new_series,add_ser]))
# Out:
# a    1
# b    2
# c    3
# d    4
# e    0
# f    5
# 1    6
# 2    7
# 3    8
# dtype: int64

# %%
a=[]
for i in range(2):
    
    for i in range(50):
        a.append((random()*100+1))
plt.plot(a)
plt.title("random numbers")
plt.show()

# %%
print(a)
# Out:
# [31.18580954210418, 60.836108265037645, 35.075668737122555, 95.31416606300823, 91.33497634511893, 44.27115993515278, 14.268981263439073, 51.16139983770065, 96.32219174931211, 14.197857053503126, 75.34954494228826, 55.91358751142171, 9.159950223434132, 20.85776467826924, 99.28090481805829, 67.57222017843914, 40.73170068205408, 80.30699772068193, 41.02831847779647, 96.61286656240382, 49.051096533619585, 33.46521025364208, 48.97553033107283, 47.55107353418483, 95.66963705244692, 68.9979906632808, 82.46024480958792, 80.9974092809999, 76.80100487012815, 23.01083373843451, 63.929673555528886, 35.01659139326823, 7.79555365963227, 74.94825073063394, 72.07075264007408, 36.467584848419506, 75.37323492882079, 42.433872551331284, 38.37129245574303, 74.19606958362698, 91.24698332922095, 80.27032191282404, 1.0071344107192783, 73.83247559622797, 54.085648946314855, 15.37550149039245, 91.85531025500762, 85.4242466118483, 75.73163294129178, 4.34032453894798, 47.682988845635656, 60.562048890656314, 73
# ...
